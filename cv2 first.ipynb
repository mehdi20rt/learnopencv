# %%
import cv2 
import numpy as np
img = cv2.imread('./cv2/input.jpg')
cv2.imshow('gav',img)
cv2.waitKey()
cv2.destroyAllWindows()
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (600, 800, 3)

# %%
cv2.imwrite('output.jpg',img)
cv2.imwrite('output.png',img)
# Out:
# True

# %%
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
plt.imshow(img[:,:,::-1])

# %%
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2XYZ)
plt.imshow(rgb_img)

# %%
# taghire range to saze delkhah --> (gbr) to (brg) with  ::-1
img[200:400, 450:550, :] = (150 , 120 , 255)
plt.imshow(img[...,::-1])
